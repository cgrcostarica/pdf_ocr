# %% [markdown]
# <a href="https://colab.research.google.com/github/cgrcostarica/pdf_ocr/blob/main/PDF_OCR_Probado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convierta sus PDF en formato OCR

# %% [markdown]
# Comienza cargando las librerías. Dele click en el boton play para correr la intalación de librerías.

# %% [markdown]
# ## Importación de librerías

# %% [markdown]
# Est código se basa en el siguiente desarrollo : https://github.com/jbarlow83/OCRmyPDF
# Todo lo demás es una dependencia obligatoria.

# %%
! apt install tesseract-ocr
! apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !pip install pytesseract

# %%
# !apt install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ghostscript is already the newest version (9.55.0~dfsg1-0ubuntu5.6).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !pip install ocrmypdf

# %%
# !ocrmypdf --help
# Out:
# usage: ocrmypdf [-h] [-l LANGUAGES] [--image-dpi DPI]
#                 [--output-type {pdfa,pdf,pdfa-1,pdfa-2,pdfa-3,none}] [--sidecar [FILE]]
#                 [--version] [-j N] [-q] [-v [VERBOSE]] [--title TITLE] [--author AUTHOR]
#                 [--subject SUBJECT] [--keywords KEYWORDS] [-r] [--remove-background] [-d] [-c]
#                 [-i] [--unpaper-args UNPAPER_ARGS] [--oversample DPI] [--remove-vectors] [-f] [-s]
#                 [--redo-ocr] [--skip-big MPixels] [--invalidate-digital-signatures]
#                 [--pages PAGES] [--max-image-mpixels MPixels]
#                 [--pdf-renderer {auto,hocr,sandwich,hocrdebug}]
#                 [--rotate-pages-threshold CONFIDENCE] [--fast-web-view MEGABYTES]
#                 [--continue-on-soft-render-error] [--plugin PLUGINS] [-k] [--tesseract-config CFG]
#                 [--tesseract-pagesegmode PSM] [--tesseract-oem MODE]
#                 [--tesseract-thresholding METHOD] [--tesseract-timeout SECONDS]
# ...

# %%
from ctypes.util import find_library
find_library("gs")
# Out:
# 'libgs.so.9'

# %%
#esto sirve para vincular colab
import pandas as pd
# %load_ext google.colab.data_table

# %%
#vamos a crear las carpetas de input y output
# !mkdir input_papers
# !mkdir output_papers
# Out:
# mkdir: cannot create directory ‘input_papers’: File exists
# mkdir: cannot create directory ‘output_papers’: File exists

# %% [markdown]
# ## Ejecución del OCR

# %% [markdown]
# <==== dar click en el logo de la carpeta donde aparecerán 2 carpetas una de input y otra de output.
# Craga los archivos subiendos al input
# Los archivos de salida estarán ubicados en la carpeta 'output_papers'. (Si las carpetas no son visibles, actualiza el explorador con el botón de actualización)

# %%
import os
file_list = []

input_folder_path = "/content/input_papers"
output_folder_path = "/content/output_papers"

for filename in os.listdir(input_folder_path):
    if filename.endswith("pdf"):
      file_list.append(filename)

print("The following files will be converted : ")
pd.DataFrame(file_list, columns=["Filename"])
# Out:
# The following files will be converted :
#                  Filename
# 0  DIS. EN COMISIÓN 1.pdf

# %% [markdown]
# Advertencia: varios minutos por archivo, por favor, verifica la lista anterior antes de continuar.

# %%
for filename in file_list:
  print("Converting : " + filename)
  input_filename = input_folder_path+'/'+filename
  output_filename = output_folder_path+'/'+filename
  # !ocrmypdf --force-ocr "{input_filename}" "{output_filename}"
# Out:
# Converting : DIS. EN COMISIÓN 1.pdf
# Scanning contents     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 2269/2269 0:00:00
# Start processing 2 pages concurrently                                                      ]8;id=647677;file:///usr/local/lib/python3.10/dist-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=923088;file:///usr/local/lib/python3.10/dist-packages/ocrmypdf/_pipelines/ocr.py#97\97]8;;\
#     7  lots of diacritics - possibly poor OCR                                       ]8;id=506449;file:///usr/local/lib/python3.10/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=552674;file:///usr/local/lib/python3.10/dist-packages/ocrmypdf/_exec/tesseract.py#240\240]8;;\
# ...
